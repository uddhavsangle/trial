# %%
import pandas as pd

# %% [markdown]
# # how to create dataframe

# %%
df2=pd.read_csv('New Text Document.csv') #read csv

# %%
df2
# Out:
#     Index  Organization Id                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# ...

# %%
df1=pd.read_excel('Table.xlsx')  #read excel   sheet_name=""

# %%
df1
# Out:
#     Mark Sheet    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN           NaN        NaN        NaN        NaN        NaN
# 1      Roll No  Student Name       City      Class    Marathi      Hindi
# 2            1         anand  Ahmedabad       VIII         90         45
# 3            2       firdous  Ahmedabad          X         76         68
# 4            3      shrikant     Badoda          X         75         71
# ..         ...           ...        ...        ...        ...        ...
# 332        331        deepak    Shirala       VIII         79         87
# 333        332     anilkumar     Kanpur       VIII         73         87
# 334        333      katariya     Mumbai         IX         87         86
# 335        334        bangad     Mumbai          X         85         74
# 336        335         bhoge       Pune         IX         84         89
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# ...

# %%
import requests

# %%
df3=pd.read_json('https://api.coindesk.com/v1/bpi/currentprice.json') #read api

# %%
df3
# Out:
#                                  time  \
# updated     Feb 26, 2023 09:49:00 UTC
# updatedISO  2023-02-26T09:49:00+00:00
# updateduk   Feb 26, 2023 at 09:49 GMT
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %% [markdown]
# df3.to_html('test.html')

# %%
df3.to_html('test.html')#save dataframe in any form

# %%
thisdict = {'id':[101,102,103],'name':['udhv','ksn','sgr'],'city':['ashti','klp','arg']
}

# %%
df4=pd.DataFrame(thisdict)  #creearting dataframe using dict

# %%
df4
# Out:
#     id  name   city
# 0  101  udhv  ashti
# 1  102   ksn    klp
# 2  103   sgr    arg

# %%
dt=[('12/02/2023',4,'pune'),
   ('11/01/2023',5,'mumbai'),
   ('23/03/2022',5,'ngp')]

# dataframe from tuple

# %%
df5=pd.DataFrame(dt,columns=['DATE','TEMP','CITY'])

# %%
df5
# Out:
#          DATE  TEMP    CITY
# 0  12/02/2023     4    pune
# 1  11/01/2023     5  mumbai
# 2  23/03/2022     5     ngp

# %%
df5.index=['a','b','c']

# %%
df5
# Out:
#          DATE  TEMP    CITY
# a  12/02/2023     4    pune
# b  11/01/2023     5  mumbai
# c  23/03/2022     5     ngp

# %%
# fetching data from html page
df6=pd.read_html('https://www.w3schools.com/html/html_tables.asp')

# %%
df6[1]
# Out:
#           Tag                                        Description
# 0     <table>                                    Defines a table
# 1        <th>                   Defines a header cell in a table
# 2        <tr>                           Defines a row in a table
# 3        <td>                          Defines a cell in a table
# 4   <caption>                            Defines a table caption
# 5  <colgroup>  Specifies a group of one or more columns in a ...
# 6       <col>  Specifies column properties for each column wi...
# 7     <thead>               Groups the header content in a table
# 8     <tbody>                 Groups the body content in a table
# 9     <tfoot>               Groups the footer content in a table

# %%
df6.drop9('unnamed:0',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7184\1723001939.py in <module>
# ----> 1 df6.drop9('unnamed:0',axis=1,inplace=True)
#
# AttributeError: 'list' object has no attribute 'drop9'

# %% [markdown]
# # data frames shape (r&c)

# %%
df2
# Out:
#     Index  Organization Id                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# ...

# %%
#for datatypes
df2.dtypes
# Out:
# Index                   int64
# Organization Id        object
# Name                   object
# Website                object
# Country                object
# Description            object
# Founded                 int64
# Industry               object
# Number of employees     int64
# dtype: object

# %%
df2.columns
# Out:
# Index(['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
#for removing /drop space column
df2.drop('unnamed:0',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7184\3835535536.py in <module>
#       1 #for removing /drop space column
# ----> 2 df2.drop('unnamed:0',axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
df2.head(5)

# %%
df2.tail(4)
# Out:
#     Index  Organization Id                       Name  \
# 16     17  68139b5C4De03B4  Bowers, Guerra and Krause
# 17     18  5c2EffEfdba2BdF            Mckenzie-Melton
# 18     19  ba179F19F7925f5                Branch-Mann
# 19     20  c1Ce9B350BAc66b             Weiss and Sons
#
#                                Website    Country  \
# 16  http://www.carrillo-nicholson.com/     Uganda
# 17        http://montoya-thompson.com/  Hong Kong
# 18              http://www.lozano.com/   Botswana
# 19                https://barrett.com/      Korea
#
#                               Description  Founded  \
# 16    De-engineered transitional strategy     1972
# 17  Reverse-engineered heuristic alliance     1998
# 18              Adaptive intangible frame     1999
# 19       Sharable optimal functionalities     2011
#
#                                              Industry  Number of employees
# 16                      Primary / Secondary Education                 6986
# ...

# %%
df2.sample(2)
# Out:
#     Index  Organization Id            Name                      Website  \
# 19     20  c1Ce9B350BAc66b  Weiss and Sons         https://barrett.com/
# 9      10  738b5aDe6B1C6A5      Gaines Inc  http://sandoval-hooper.com/
#
#        Country                       Description  Founded  \
# 19       Korea  Sharable optimal functionalities     2011
# 9   Uzbekistan   Multi-lateral scalable protocol     1997
#
#                     Industry  Number of employees
# 19                  Plastics                 5984
# 9   Outsourcing / Offshoring                 9698

# %%
s = pd.Series([1, 2, 3])
s.describe() #for high end analysis
# Out:
# count    3.0
# mean     2.0
# std      1.0
# min      1.0
# 25%      1.5
# 50%      2.0
# 75%      2.5
# max      3.0
# dtype: float64

# %%
df2['Name']
# Out:
# 0                   Ferrell LLC
# 1       Mckinney, Riley and Day
# 2                    Hester Ltd
# 3                Holder-Sellers
# 4                   Mayer Group
# 5                Henry-Thompson
# 6                Hansen-Everett
# 7                 Mcintosh-Mora
# 8                      Carr Inc
# 9                    Gaines Inc
# 10                   Kidd Group
# 11                 Crane-Clarke
# 12     Keller, Campos and Black
# 13                  Glover-Pope
# 14               Pacheco-Spears
# 15                  Hodge-Ayers
# 16    Bowers, Guerra and Krause
# 17              Mckenzie-Melton
# 18                  Branch-Mann
# 19               Weiss and Sons
# Name: Name, dtype: object

# %%
df2[['Index','Name','Country']]
# Out:
#     Index                       Name                            Country
# 0       1                Ferrell LLC                   Papua New Guinea
# 1       2    Mckinney, Riley and Day                            Finland
# 2       3                 Hester Ltd                              China
# 3       4             Holder-Sellers                       Turkmenistan
# 4       5                Mayer Group                          Mauritius
# 5       6             Henry-Thompson                            Bahamas
# 6       7             Hansen-Everett                           Pakistan
# 7       8              Mcintosh-Mora  Heard Island and McDonald Islands
# 8       9                   Carr Inc                             Kuwait
# 9      10                 Gaines Inc                         Uzbekistan
# 10     11                 Kidd Group          Bouvet Island (Bouvetoya)
# 11     12               Crane-Clarke                            Denmark
# ...

# %%
df2[[col for col in df2.columns if col not in ['Index','Name','Country']]]  #if we dont want some col
# Out:
#     Organization Id                             Website  \
# 0   FAB0d41d5b5d22c                  https://price.net/
# 1   6A7EdDEA9FaDC52      http://www.hall-buchanan.info/
# 2   0bFED1ADAE4bcC1           http://sullivan-reed.com/
# 3   2bFC1Be8a4ce42f                 https://becker.com/
# 4   9eE8A6a4Eb96C24              http://www.brewer.com/
# 5   cC757116fe1C085                   http://morse.net/
# 6   219233e8aFF1BC3               https://www.kidd.org/
# 7   ccc93DCF81a31CD             https://www.brooks.com/
# 8   0B4F93aA06ED03e                    http://ross.com/
# 9   738b5aDe6B1C6A5         http://sandoval-hooper.com/
# 10  AE61b8Ffebbc476               http://www.lyons.com/
# 11  eb3B7D06cCdD609           https://www.sandoval.com/
# 12  8D0c29189C9798B            https://www.garner.info/
# 13  D2c91cc03CA394c               http://www.silva.biz/
# 14  C8AC1eaf9C036F4                https://aguilar.com/
# 15  b5D10A14f7a8AfE      http://www.archer-elliott.com/
# ...

# %%
#rename col   #for col axis=1, row-axis=0
df2.rename({'Organization Id':'Iid'},axis=1)
# Out:
#     Index              Iid                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# ...

# %%
# loc --df.loc[rows,col]

# %%
df2.loc[:,['Index','Name']]
# Out:
#     Index                       Name
# 0       1                Ferrell LLC
# 1       2    Mckinney, Riley and Day
# 2       3                 Hester Ltd
# 3       4             Holder-Sellers
# 4       5                Mayer Group
# 5       6             Henry-Thompson
# 6       7             Hansen-Everett
# 7       8              Mcintosh-Mora
# 8       9                   Carr Inc
# 9      10                 Gaines Inc
# 10     11                 Kidd Group
# 11     12               Crane-Clarke
# 12     13   Keller, Campos and Black
# 13     14                Glover-Pope
# 14     15             Pacheco-Spears
# 15     16                Hodge-Ayers
# 16     17  Bowers, Guerra and Krause
# 17     18            Mckenzie-Melton
# 18     19                Branch-Mann
# 19     20             Weiss and Sons

# %%
df2.loc[2:3,['Index','Name']]  #range
# Out:
#    Index            Name
# 2      3      Hester Ltd
# 3      4  Holder-Sellers

# %%
df2.loc[[2,4,6,3],['Index','Name']] #for selected
# Out:
#    Index            Name
# 2      3      Hester Ltd
# 4      5     Mayer Group
# 6      7  Hansen-Everett
# 3      4  Holder-Sellers

# %%
dfs=df2.set_index('Index')

# %%
dfs
# Out:
#        Organization Id                       Name  \
# Index
# 1      FAB0d41d5b5d22c                Ferrell LLC
# 2      6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 3      0bFED1ADAE4bcC1                 Hester Ltd
# 4      2bFC1Be8a4ce42f             Holder-Sellers
# 5      9eE8A6a4Eb96C24                Mayer Group
# 6      cC757116fe1C085             Henry-Thompson
# 7      219233e8aFF1BC3             Hansen-Everett
# 8      ccc93DCF81a31CD              Mcintosh-Mora
# 9      0B4F93aA06ED03e                   Carr Inc
# 10     738b5aDe6B1C6A5                 Gaines Inc
# 11     AE61b8Ffebbc476                 Kidd Group
# 12     eb3B7D06cCdD609               Crane-Clarke
# 13     8D0c29189C9798B   Keller, Campos and Black
# 14     D2c91cc03CA394c                Glover-Pope
# 15     C8AC1eaf9C036F4             Pacheco-Spears
# 16     b5D10A14f7a8AfE                Hodge-Ayers
# 17     68139b5C4De03B4  Bowers, Guerra and Krause
# 18     5c2EffEfdba2BdF            Mckenzie-Melton
# ...

# %%
df2.loc[0,:]
# Out:
# Index                                                    1
# Organization Id                            FAB0d41d5b5d22c
# Name                                           Ferrell LLC
# Website                                 https://price.net/
# Country                                   Papua New Guinea
# Description            Horizontal empowering knowledgebase
# Founded                                               1990
# Industry                                          Plastics
# Number of employees                                   3498
# Name: 0, dtype: object

# %%
#iloc - integer location , end index not include

# %%
df2.iloc[1:3,:]
# Out:
#    Index  Organization Id                     Name  \
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
#
#                           Website  Country  \
# 1  http://www.hall-buchanan.info/  Finland
# 2       http://sullivan-reed.com/    China
#
#                            Description  Founded                     Industry  \
# 1  User-centric system-worthy leverage     2015  Glass / Ceramics / Concrete
# 2       Switchable scalable moratorium     1971                Public Safety
#
#    Number of employees
# 1                 4952
# 2                 5287

# %%
df2.iloc[2:5,3:6]
# Out:
#                      Website       Country  \
# 2  http://sullivan-reed.com/         China
# 3        https://becker.com/  Turkmenistan
# 4     http://www.brewer.com/     Mauritius
#
#                                       Description
# 2                  Switchable scalable moratorium
# 3  De-engineered systemic artificial intelligence
# 4              Synchronized needs-based challenge

# %%
df2.iloc[[i for i in df2.index if i not in[0,3]]]
# Out:
#     Index  Organization Id                       Name  \
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# 16     17  68139b5C4De03B4  Bowers, Guerra and Krause
# 17     18  5c2EffEfdba2BdF            Mckenzie-Melton
# ...

# %%
#new col addition

# %%
df2['new col']='test'

# %%
df2
# Out:
#     Index  Organization Id                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# ...

# %%
 df2.iloc[3,7]='aws'

# %%
df2
# Out:
#     Index  Organization Id                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# ...

# %%
# drop column

# %%
df=df2.drop('new col',axis=1)

# %%
df
# Out:
#     Index  Organization Id                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# ...

# %%
df=df2.drop(columns=['new col','Description'],axis=1) #multi col delete

# %%
df
# Out:
#     Index  Organization Id                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# ...

# %%
#for delete no of record

# %%
df.drop([r for r in range (5,10)])
# Out:
#     Index  Organization Id                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# 16     17  68139b5C4De03B4  Bowers, Guerra and Krause
# 17     18  5c2EffEfdba2BdF            Mckenzie-Melton
# 18     19  ba179F19F7925f5                Branch-Mann
# 19     20  c1Ce9B350BAc66b             Weiss and Sons
#
#                                Website                    Country  Founded  \
# ...

# %%
df.drop(list(range(5)))
# Out:
#     Index  Organization Id                       Name  \
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# 16     17  68139b5C4De03B4  Bowers, Guerra and Krause
# 17     18  5c2EffEfdba2BdF            Mckenzie-Melton
# 18     19  ba179F19F7925f5                Branch-Mann
# 19     20  c1Ce9B350BAc66b             Weiss and Sons
#
#                                Website                            Country  \
# ...

# %%
df
# Out:
#     Index  Organization Id                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# ...

# %%
df['new']='trial'

# %%
df
# Out:
#     Index  Organization Id                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# ...

# %%
df['add']=df['age']+df['temp']  #addition of two column in one
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['Name'].unique()
# Out:
# array(['Ferrell LLC', 'Mckinney, Riley and Day', 'Hester Ltd',
#        'Holder-Sellers', 'Mayer Group', 'Henry-Thompson',
#        'Hansen-Everett', 'Mcintosh-Mora', 'Carr Inc', 'Gaines Inc',
#        'Kidd Group', 'Crane-Clarke', 'Keller, Campos and Black',
#        'Glover-Pope', 'Pacheco-Spears', 'Hodge-Ayers',
#        'Bowers, Guerra and Krause', 'Mckenzie-Melton', 'Branch-Mann',
#        'Weiss and Sons'], dtype=object)

# %%
df['Number of employees'].value_counts(ascending=True)
# Out:
# 3498    1
# 4589    1
# 6986    1
# 8508    1
# 769     1
# 9079    1
# 2862    1
# 9011    1
# 7473    1
# 9698    1
# 8167    1
# 4389    1
# 7832    1
# 4914    1
# 7870    1
# 921     1
# 5287    1
# 4952    1
# 7961    1
# 5984    1
# Name: Number of employees, dtype: int64

# %%
df.sort_values('Number of employees')
# Out:
#     Index  Organization Id                       Name  \
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 17     18  5c2EffEfdba2BdF            Mckenzie-Melton
# 5       6  cC757116fe1C085             Henry-Thompson
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 19     20  c1Ce9B350BAc66b             Weiss and Sons
# 16     17  68139b5C4De03B4  Bowers, Guerra and Krause
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 18     19  ba179F19F7925f5                Branch-Mann
# 8       9  0B4F93aA06ED03e                   Carr Inc
# ...

# %%
#filter record based on condition

# %%
df[df['Country']=='China']
# Out:
#    Index  Organization Id        Name                    Website Country  \
# 2      3  0bFED1ADAE4bcC1  Hester Ltd  http://sullivan-reed.com/   China
#
#    Founded       Industry  Number of employees    new
# 2     1971  Public Safety                 5287  trial

# %%
import datetime

# %%
df2.sort_values('Founded')
# Out:
#     Index  Organization Id                       Name  \
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 16     17  68139b5C4De03B4  Bowers, Guerra and Krause
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 17     18  5c2EffEfdba2BdF            Mckenzie-Melton
# 18     19  ba179F19F7925f5                Branch-Mann
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 19     20  c1Ce9B350BAc66b             Weiss and Sons
# 13     14  D2c91cc03CA394c                Glover-Pope
# ...

# %%
df1=pd.read_excel('Data_final_pivot_table.xlsx')

# %%
df1
# Out:
#       Client_Code                           Client_Name  \
# 0        19210001     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
df1[df1['District']=='Aurangabad']
# Out:
#      Client_Code                   Client_Name  \
# 638     16210001       Shree Adinath Computers
# 639     16210002           Sarvadnya Computers
# 640     16210003              Atharv Computers
# 641     16210007  Gurukrupa Computer Institute
# 642     16210008       Biit Computer Education
# ..           ...                           ...
# 852     16210500               yugan computers
# 853     16210502  Shree Sai Computers Golegaon
# 854     16210503    ADITICOMPUTERS18@GMAIL.COM
# 855     16210505               DISHA COMPUTERS
# 856     16210510             Shreeram Infotech
#
#                                                Address  \
# 638  PISHOR NAKA, NEAR TIRUPATI HOSPITAL ,CHALISGAO...
# 639  Plot No. 16, NS-1, F-Sector, Ashta Vinayak Mar...
# 640  Opp.Saptapadi hall,Near Baliram patil h.school...
# 641  BEHIND MAHARASHTRA GRAMIN BANK GANESH CHOWK NU...
# 642  Opp. Wani Mangal karayalay (Galli) Shriram Col...
# ..                                                 ...
# ...

# %%
df1[df1['District']=='Aurangabad'][['Pin','Taluka']]
# Out:
#         Pin      Taluka
# 638  431103      Kannad
# 639  431005  Aurangabad
# 640  431003  Aurangabad
# 641  431109    Gangapur
# 642  431103      Kannad
# ..      ...         ...
# 852  431007  Aurangabad
# 853  431112      Sillod
# 854  431118     Soegaon
# 855  431110    Gangapur
# 856  431010  Aurangabad
#
# [219 rows x 2 columns]

# %%
df1[(df1['District']=='Aurangabad') & (df1['Taluka']=='Kannad')]   #applyting two condition
# Out:
#      Client_Code                                Client_Name  \
# 638     16210001                    Shree Adinath Computers
# 642     16210008                    Biit Computer Education
# 657     16210034                          Comtech Computers
# 676     16210076  Shri C.S.P.Mandals Shivaji College Kannad
# 679     16210088                           Prince Computers
# 681     16210092                           M-Tech Computers
# 696     16210126                    Sadguru Computer Centre
# 704     16210151                          Comtech Computers
# 756     16210275                            ANSAI COMPUTERS
# 764     16210297                            MANSI COMPUTERS
# 778     16210324  PRASAD COMPUTER & DIGITAL CLASS NACHANWEL
# 783     16210329                   SHREE COMPUTERS, HATNOOR
# 789     16210347                            Rohan Computers
# 794     16210362                     Vidya Mandir Computers
# 798     16210372                            NAKSH COMPUTERS
# ...

# %%
df1['Total Business in 2021'].max()
# Out:
# 286250

# %%
df1['Total Business in 2021'].min()
# Out:
# 250

# %%
df1['Total Business in 2021'].std()
# Out:
# 36261.594762909226

# %%
df1['Total Business in 2021'].median()
# Out:
# 36875.0

# %%
df=pd.read_csv('weather.csv')

# %%
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df2[df2['avg temp']==df2['avg temp'].max()]

# %%
import requests

# %%
d=requests.get('api.........').json()

# %%
pd.DataFrame(d)

# %%
df2
# Out:
#     Index  Organization Id                       Name  \
# 0       1  FAB0d41d5b5d22c                Ferrell LLC
# 1       2  6A7EdDEA9FaDC52    Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                 Hester Ltd
# 3       4  2bFC1Be8a4ce42f             Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                Mayer Group
# 5       6  cC757116fe1C085             Henry-Thompson
# 6       7  219233e8aFF1BC3             Hansen-Everett
# 7       8  ccc93DCF81a31CD              Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                   Carr Inc
# 9      10  738b5aDe6B1C6A5                 Gaines Inc
# 10     11  AE61b8Ffebbc476                 Kidd Group
# 11     12  eb3B7D06cCdD609               Crane-Clarke
# 12     13  8D0c29189C9798B   Keller, Campos and Black
# 13     14  D2c91cc03CA394c                Glover-Pope
# 14     15  C8AC1eaf9C036F4             Pacheco-Spears
# 15     16  b5D10A14f7a8AfE                Hodge-Ayers
# ...

# %%
df2[df2['Founded']>2000]     #if we want some rec gt 2000
# Out:
#     Index  Organization Id                      Name  \
# 1       2  6A7EdDEA9FaDC52   Mckinney, Riley and Day
# 3       4  2bFC1Be8a4ce42f            Holder-Sellers
# 6       7  219233e8aFF1BC3            Hansen-Everett
# 10     11  AE61b8Ffebbc476                Kidd Group
# 11     12  eb3B7D06cCdD609              Crane-Clarke
# 12     13  8D0c29189C9798B  Keller, Campos and Black
# 13     14  D2c91cc03CA394c               Glover-Pope
# 19     20  c1Ce9B350BAc66b            Weiss and Sons
#
#                            Website                    Country  \
# 1   http://www.hall-buchanan.info/                    Finland
# 3              https://becker.com/               Turkmenistan
# 6            https://www.kidd.org/                   Pakistan
# 10           http://www.lyons.com/  Bouvet Island (Bouvetoya)
# 11       https://www.sandoval.com/                    Denmark
# 12        https://www.garner.info/                    Liberia
# ...

# %%
df2[(df2['Founded']>2000) & (df2['Index']>10)]    # apply 2 condition
# Out:
#     Index  Organization Id                      Name  \
# 10     11  AE61b8Ffebbc476                Kidd Group
# 11     12  eb3B7D06cCdD609              Crane-Clarke
# 12     13  8D0c29189C9798B  Keller, Campos and Black
# 13     14  D2c91cc03CA394c               Glover-Pope
# 19     20  c1Ce9B350BAc66b            Weiss and Sons
#
#                       Website                    Country  \
# 10      http://www.lyons.com/  Bouvet Island (Bouvetoya)
# 11  https://www.sandoval.com/                    Denmark
# 12   https://www.garner.info/                    Liberia
# 13      http://www.silva.biz/       United Arab Emirates
# 19       https://barrett.com/                      Korea
#
#                                 Description  Founded  \
# 10            Proactive foreground paradigm     2001
# 11     Front-line clear-thinking encryption     2014
# 12        Ameliorated directional emulation     2020
# 13  Persevering contextually-based approach     2013
# ...

# %%
df2['Founded'].max()
# Out:
# 2020

# %%
df2[df2['Founded']==df2['Founded'].max()][['Index','Website','Country']]
# Out:
#     Index                   Website  Country
# 12     13  https://www.garner.info/  Liberia

# %% [markdown]
# # data modification

# %%
d={'name':['suresh','naresh','keshav','pratik','suresh','sonali'],
   'id':[15,16,17,18,15,20],
   'city':['pune','mumbai','bang','nashik','pune','satara'],
   'salary':[75000,95000,85000,60000,75000,85000],
    'gen':['m','m','m','m','m','f'],
  'home':['2 bhk','3 bhk','2 bhk','2 bhk','3 bhk','2 bhk']}

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#      name  id    city  salary gen   home
# 0  suresh  15    pune   75000   m  2 bhk
# 1  naresh  16  mumbai   95000   m  3 bhk
# 2  keshav  17    bang   85000   m  2 bhk
# 3  pratik  18  nashik   60000   m  2 bhk
# 4  suresh  15    pune   75000   m  3 bhk
# 5  sonali  20  satara   85000   f  2 bhk

# %%
p=pd.Series(data=['suresh',15,'pune',75000])

# %%
p
# Out:
# 0    suresh
# 1        15
# 2      pune
# 3     75000
# dtype: object

# %%
df1=pd.concat([df,p],axis=1)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      name  id    city  salary gen
# 0  suresh  15    pune   75000   m
# 1  naresh  16  mumbai   95000   m
# 2  keshav  17    bang   85000   m
# 3  pratik  18  nashik   60000   m
# 5  sonali  20  satara   85000   f

# %%
# map,apply

# %%
df['encoded_gen2']=df['gen'].map({'m':1,'f':0})

# %%
df
# Out:
#      name  id    city  salary gen  encoded_gen
# 0  suresh  15    pune   75000   m            1
# 1  naresh  16  mumbai   95000   m            1
# 2  keshav  17    bang   85000   m            1
# 3  pratik  18  nashik   60000   m            1
# 5  sonali  20  satara   85000   f            0

# %%
def encode(r):
    if r=="m":
        return 1
    else:
        return 0

# %%
df['encoded_gen_by_using_normal_fun']=df['gen'].map(encode)

# %%
df
# Out:
#      name  id    city  salary gen  encoded_gen  \
# 0  suresh  15    pune   75000   m            1
# 1  naresh  16  mumbai   95000   m            1
# 2  keshav  17    bang   85000   m            1
# 3  pratik  18  nashik   60000   m            1
# 5  sonali  20  satara   85000   f            0
#
#    encoded_gen_by_using_normal_fun
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 5                                0

# %%
#map--only for single column
#apply--single or whole df

# %%
df['encoded_gen1']=df['gen'].apply(encode)

# %%
df
# Out:
#      name  id    city  salary gen   home  encoded_gen_by_using_normal_fun  \
# 0  suresh  15    pune   75000   m  2 bhk                                1
# 1  naresh  16  mumbai   95000   m  3 bhk                                1
# 2  keshav  17    bang   85000   m  2 bhk                                1
# 3  pratik  18  nashik   60000   m  2 bhk                                1
# 4  suresh  15    pune   75000   m  3 bhk                                1
# 5  sonali  20  satara   85000   f  2 bhk                                0
#
#    encoded_gen1
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# 5             0

# %%
df.rename({'gen1':'gen2'},axis=1)
# Out:
#     name1  id1   city1  salary1 gen2  encoded_gen1  \
# 0  suresh   15    pune    75000    m             1
# 1  naresh   16  mumbai    95000    m             1
# 2  keshav   17    bang    85000    m             1
# 3  pratik   18  nashik    60000    m             1
# 5  sonali   20  satara    85000    f             0
#
#    encoded_gen_by_using_normal_fun1
# 0                                 1
# 1                                 1
# 2                                 1
# 3                                 1
# 5                                 0

# %%
#for rename multiple column at a time

# %%
df.columns
# Out:
# Index(['name', 'id', 'city', 'salary', 'gen', 'encoded_gen',
#        'encoded_gen_by_using_normal_fun'],
#       dtype='object')

# %%
df.columns=['name1', 'id1', 'city1', 'salary1', 'gen1', 'encoded_gen1',
       'encoded_gen_by_using_normal_fun1']

# %%
df
# Out:
#     name1  id1   city1  salary1 gen1  encoded_gen1  \
# 0  suresh   15    pune    75000    m             1
# 1  naresh   16  mumbai    95000    m             1
# 2  keshav   17    bang    85000    m             1
# 3  pratik   18  nashik    60000    m             1
# 5  sonali   20  satara    85000    f             0
#
#    encoded_gen_by_using_normal_fun1
# 0                                 1
# 1                                 1
# 2                                 1
# 3                                 1
# 5                                 0

# %%
def encodes(s):
    if s>75000 and s>80000:
        return 'good'
    elif s>80000 and s>9500:
        return 'very good'
    else:
        return 'best'

# %%
df['new_sal']=df['salary1'].apply(encodes)

# %%
df
# Out:
#     name1  id1   city1  salary1 gen1  encoded_gen1  \
# 0  suresh   15    pune    75000    m             1
# 1  naresh   16  mumbai    95000    m             1
# 2  keshav   17    bang    85000    m             1
# 3  pratik   18  nashik    60000    m             1
# 5  sonali   20  satara    85000    f             0
#
#    encoded_gen_by_using_normal_fun1 new_sal
# 0                                 1    best
# 1                                 1    good
# 2                                 1    good
# 3                                 1    best
# 5                                 0    good

# %%
#if we giving data to mc then need to feed data in numeric form

# %%
df
# Out:
#      name  id    city  salary gen   home
# 0  suresh  15    pune   75000   m  2 bhk
# 1  naresh  16  mumbai   95000   m  3 bhk
# 2  keshav  17    bang   85000   m  2 bhk
# 3  pratik  18  nashik   60000   m  2 bhk
# 4  suresh  15    pune   75000   m  3 bhk
# 5  sonali  20  satara   85000   f  2 bhk

# %%
df['home']=df['home'].apply(lambda x:x.split(' ')[0])

# %%
df
# Out:
#      name  id    city  salary gen home
# 0  suresh  15    pune   75000   m    2
# 1  naresh  16  mumbai   95000   m    3
# 2  keshav  17    bang   85000   m    2
# 3  pratik  18  nashik   60000   m    2
# 4  suresh  15    pune   75000   m    3
# 5  sonali  20  satara   85000   f    2

# %%
df['home'].unique()
# Out:
# array(['2', '3'], dtype=object)

# %% [markdown]
# # handling missing value in csv

# %%
df
# Out:
#      name  id    city  salary gen home
# 0  suresh  15    pune   75000   m    2
# 1  naresh  16  mumbai   95000   m    3
# 2  keshav  17    bang   85000   m    2
# 3  pratik  18  nashik   60000   m    2
# 4  suresh  15    pune   75000   m    3
# 5  sonali  20  satara   85000   f    2

# %%
df1=pd.read_csv('missing.csv')

# %%
df1
# Out:
#     id    name   city  aadhar    pan
# 0  101  uddhav  ashti   545.0  12334
# 1  102     ksn    NaN     NaN  53635
# 2  103     sgr    NaN  4534.0    454
# 3  104     sdf    sdf   324.0   3654

# %%
df1.dropna()  #this method drop row  of  missing value
# Out:
#     id    name   city  aadhar    pan
# 0  101  uddhav  ashti   545.0  12334

# %%
#how ---1.any 2.all

# %%
df1
# Out:
#     id    name   city  aadhar    pan
# 0  101  uddhav  ashti   545.0  12334
# 1  102     ksn    NaN     NaN  53635
# 2  103     sgr    NaN  4534.0    454

# %%
dfn=df1.dropna(how='any')

# %%
dfn
# Out:
#     id    name   city  aadhar    pan
# 0  101  uddhav  ashti   545.0  12334

# %%
#threshould --this perticular record must have atleast non null val in given df

# %%
df1.dropna(thresh=5)
# Out:
#     id    name   city  aadhar    pan
# 0  101  uddhav  ashti   545.0  12334
# 3  104     sdf    sdf   324.0   3654

# %%
#fillna ---filling at the place of null

# %%
df1.fillna(0)
# Out:
#     id    name   city  aadhar    pan
# 0  101  uddhav  ashti   545.0  12334
# 1  102     ksn      0     0.0  53635
# 2  103     sgr      0  4534.0    454
# 3  104     sdf    sdf   324.0   3654

# %%
dfa=pd.read_csv('missing.csv')

# %%
dfa
# Out:
#     id    name   city  aadhar    pan
# 0  101  uddhav  ashti   545.0  12334
# 1  102     ksn    NaN     NaN  53635
# 2  103     sgr    NaN  4534.0    454
# 3  104     sdf    sdf   324.0   3654

# %%
dfa['city']=dfa['city'].fillna('a')

# %%
dfa
# Out:
#     id    name   city  aadhar    pan
# 0  101  uddhav  ashti   545.0  12334
# 1  102     ksn      a     NaN  53635
# 2  103     sgr      a  4534.0    454
# 3  104     sdf    sdf   324.0   3654

# %%
#forword fill--null before value pass at the place pf null
dfa['aadhar'].fillna(method='ffill')
# Out:
# 0     545.0
# 1     545.0
# 2    4534.0
# 3     324.0
# Name: aadhar, dtype: float64

# %%
dfa
# Out:
#     id    name   city  aadhar    pan
# 0  101  uddhav  ashti   545.0  12334
# 1  102     ksn      a     NaN  53635
# 2  103     sgr      a  4534.0    454
# 3  104     sdf    sdf   324.0   3654

# %%
#backword fill--null after value pass at the place pf null
dfa['aadhar'].fillna(method='bfill')
# Out:
# 0     545.0
# 1    4534.0
# 2    4534.0
# 3     324.0
# Name: aadhar, dtype: float64

# %%
df=pd.read_csv('weather.csv')

# %%
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
obj=df.groupby('Station.State')

# %%
obj.get_group('Wyoming')
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 310                  0.00  2016-01-03           1             3       2016
# 311                  0.00  2016-01-03           1             3       2016
# 312                  0.00  2016-01-03           1             3       2016
# 313                  0.00  2016-01-03           1             3       2016
# 314                  0.00  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
obj.max()
# Out:
#                 Data.Precipitation   Date.Full  Date.Month  Date.Week of  \
# Station.State
# Alabama                       4.44  2017-01-01          12            31
# Alaska                       10.34  2017-01-01          12            31
# Arizona                       2.28  2017-01-01          12            31
# Arkansas                      6.08  2017-01-01          12            31
# California                    6.60  2017-01-01          12            31
# Colorado                      1.82  2017-01-01          12            31
# Connecticut                   2.81  2017-01-01          12            31
# DE                            3.27  2017-01-01          12            31
# Delaware                      3.27  2017-01-01          12            31
# Florida                      15.19  2017-01-01          12            31
# Georgia                      11.52  2017-01-01          12            31
# Hawaii                       14.03  2017-01-01          12            31
# ...

# %%
obj.min()
# Out:
#                 Data.Precipitation   Date.Full  Date.Month  Date.Week of  \
# Station.State
# Alabama                       0.00  2016-01-03           1             1
# Alaska                        0.00  2016-01-03           1             1
# Arizona                       0.00  2016-01-03           1             1
# Arkansas                      0.00  2016-01-03           1             1
# California                    0.00  2016-01-03           1             1
# Colorado                      0.00  2016-01-03           1             1
# Connecticut                   0.00  2016-01-03           1             1
# DE                            0.00  2016-01-03           1             1
# Delaware                      0.00  2016-01-03           1             1
# Florida                       0.00  2016-01-03           1             1
# Georgia                       0.00  2016-01-03           1             1
# Hawaii                        0.00  2016-01-03           1             1
# ...

# %%
obj.describe()
# Out:
#                Data.Precipitation                                           \
#                             count      mean       std   min     25%    50%
# Station.State
# Alabama                     212.0  0.776179  0.942935  0.00  0.0000  0.400
# Alaska                     1719.0  0.566126  1.047042  0.00  0.0000  0.120
# Arizona                     265.0  0.162566  0.351791  0.00  0.0000  0.000
# Arkansas                    159.0  0.603711  0.899803  0.00  0.0050  0.220
# California                  999.0  0.323774  0.733017  0.00  0.0000  0.000
# Colorado                    318.0  0.182987  0.273182  0.00  0.0000  0.050
# Connecticut                 106.0  0.587830  0.645304  0.00  0.0850  0.390
# DE                           53.0  0.632453  0.681079  0.00  0.0500  0.370
# Delaware                     53.0  0.632453  0.681079  0.00  0.0500  0.370
# Florida                     636.0  0.891006  1.354272  0.00  0.0300  0.390
# ...

# %%
#concat--connecting of two diff dataframe baased on requirement
#similar col--additional rows
#different col--additional col will add

# %%
pune_emp={'id':[11,12,13,14],
          'name':['ketan','rahul','suresh','mukesh'],
          'sal':[75000,65000,55000,95000]}

# %%
dfp=pd.DataFrame(pune_emp)

# %%
dfp
# Out:
#    id    name    sal
# 0  11   ketan  75000
# 1  12   rahul  65000
# 2  13  suresh  55000
# 3  14  mukesh  95000

# %%
bang_emp={'id':[100,102,103,140],
          'name':['ksn','kd','tushar','ketan'],
          'sal':[75000,650004,550060,957000]}

# %%
dfb=pd.DataFrame(bang_emp)

# %%
dfb
# Out:
#     id    name     sal
# 0  100     ksn   75000
# 1  102      kd  650004
# 2  103  tushar  550060
# 3  140   ketan  957000

# %%
df_connect=pd.concat([dfp,dfb])

# %%
 df_connect
# Out:
#     id    name     sal
# 0   11   ketan   75000
# 1   12   rahul   65000
# 2   13  suresh   55000
# 3   14  mukesh   95000
# 0  100     ksn   75000
# 1  102      kd  650004
# 2  103  tushar  550060
# 3  140   ketan  957000

# %%
nashik_emp={'id':[100,102,103,140],
          'name':['ksn','kd','tushar','ketan'],
          'sal':[75000,650004,550060,957000],
           'city':['pune','mumbai','nashik','bang']}

# %%
dfn=pd.DataFrame(nashik_emp)

# %%
dfn
# Out:
#     id    name     sal    city
# 0  100     ksn   75000    pune
# 1  102      kd  650004  mumbai
# 2  103  tushar  550060  nashik
# 3  140   ketan  957000    bang

# %%
df_connect=pd.concat([dfp,dfn])

# %%
df_connect
# Out:
#     id    name     sal    city
# 0   11   ketan   75000     NaN
# 1   12   rahul   65000     NaN
# 2   13  suresh   55000     NaN
# 3   14  mukesh   95000     NaN
# 0  100     ksn   75000    pune
# 1  102      kd  650004  mumbai
# 2  103  tushar  550060  nashik
# 3  140   ketan  957000    bang

# %%
df_connect=pd.concat([dfp,dfn],axis=1)

# %%
df_connect
# Out:
#    id    name    sal   id    name     sal    city
# 0  11   ketan  75000  100     ksn   75000    pune
# 1  12   rahul  65000  102      kd  650004  mumbai
# 2  13  suresh  55000  103  tushar  550060  nashik
# 3  14  mukesh  95000  140   ketan  957000    bang

# %%
df_connect=pd.concat([dfp,dfn.iloc[2:4,:]])

# %%
df_connect
# Out:
#     id    name     sal    city
# 0   11   ketan   75000     NaN
# 1   12   rahul   65000     NaN
# 2   13  suresh   55000     NaN
# 3   14  mukesh   95000     NaN
# 2  103  tushar  550060  nashik
# 3  140   ketan  957000    bang

# %%
#series
d=pd.Series(['pune','mumbai','pune',],name='city')

# %%
d
# Out:
# 0      pune
# 1    mumbai
# 2      pune
# Name: city, dtype: object

# %%
df_with_series=pd.concat([dfp,d],axis=1)

# %%
df_with_series
# Out:
#    id    name    sal    city
# 0  11   ketan  75000    pune
# 1  12   rahul  65000  mumbai
# 2  13  suresh  55000    pune
# 3  14  mukesh  95000     NaN

# %%
#merge --for merge shoud be common column

# %%
department={'id':[45,100,950,75,690,78],'department':['it','admin','hr','fin','market','suport']}

# %%
dept=pd.DataFrame(department)

# %%
dept
# Out:
#     id department
# 0   45         it
# 1  100      admin
# 2  950         hr
# 3   75        fin
# 4  690     market
# 5   78     suport

# %%
 pd.merge(dfp,dept,on='id',how='outer')  #its like join inner,outer,left,right
# Out:
#     id    name      sal department
# 0   11   ketan  75000.0        NaN
# 1   12   rahul  65000.0        NaN
# 2   13  suresh  55000.0        NaN
# 3   14  mukesh  95000.0        NaN
# 4   45     NaN      NaN         it
# 5  100     NaN      NaN      admin
# 6  950     NaN      NaN         hr
# 7   75     NaN      NaN        fin
# 8  690     NaN      NaN     market
# 9   78     NaN      NaN     suport
